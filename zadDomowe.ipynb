# %% [markdown]
# #Zadanie domowe lab1

# %% [markdown]
# #sekcja1

# %% [markdown]
# #sekcja2

# %% [markdown]
# #sekcja3

# %% [markdown]
# ![8122.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #sekcja4
